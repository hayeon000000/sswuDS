# %% [markdown]
# 1)  최악의 경우 : 트리가 한쪽으로 완전히 치우친 경우, O(n)
#     최선의 경우 : 균형이 맞지 않더라도 트리의 높이가 최소화된 상태, O(log n)
#
# 2)  삭제한 경우이다.
#     - 17, 30, 70 중 하나가 삽입된 경우인데, 이들을 삽입하기 전이라고 가정하였을 때에도 AVL트리가 아니기 때문에 불가능하다.
#     - 삭제 : 10의 왼쪽 자식이 삭제된 경우
#
# 3)  둘 다 가능.
#     삽입 : 17이 삽입된 경우
#     삭제 : 55의 자식 노드가 삭제된 경우
#
# 4)  LR 불균형 상태.
#     노드 10 좌회전 -> 노드 40 우회전
#
#     1. 노드 10 좌회전
#
#                    40
#                  /    \
#                 20    55
#                /  \
#               10  17
#              /
#             5
#
#     2. 노드 40 우회전
#
#                    20
#                  /    \
#                 10     40
#                /  \      \
#               5   17     55
#
# 5) LR, RL의 경우. 반드시 두 번의 회전 과정이 필요하다.
#
# 6) 틀린 주장이다. 높이가 유지되는 경우가 존재한다.
#
# 7) 발생할 수 있다.
#
# 8)
#                  10(B)
#                 /    \
#              5(R)   13(B)
#             /   \      \
#           3(B)  7(B)   15(R)
#          /      /  \
#        2(R)   6(R) 8(R)
#
# 9)  1. p(R) 삽입했는데 부모 p1이 레드인 경우
#     2. p1의 형제가 레드라면 p1과 형제를 블랙으로, p2를 레드로 바꿈
#     3. p2의 부모 p3가 레드인 경우
#     4. p3의 형제가 레드라면 p3와 형제를 블랙으로, p4를 레드로 바꿈
#     5. p4의 부모 p5가 레드인 경우
#     6. p5의 형제가 레드라면 p5와 형제를 블랙으로, p6를 레드로 바꿈
#
#     최악의 경우 루트 노드까지 레드로 바뀔 수 있음. 이 경우에는 루트를 블랙으로 바꿔야 하고, 이 순간 전체 트리의 블랙 높이가 1 증가.
#
# 10)
#                                             25
#                        /                                                \
#                     6 13 19                                           34 40
#          /             |          \        \             /               |           \
#         1 2 3 4 5   7 8 9 10   15 17 18   20 23   27 28 30 31 33   35 36 37 38 39   41 45
#
#
# 11)
#                                             25
#                        /                                                \
#                     6 13 19                                           34 40
#          /             |          \            \             /               |           \
#         1 2 3 4 5   7 8 9 10   15 16 17 18   20 23   27 28 30 31 33   35 36 37 38 39   41 45
#
#
# 12)
#                                          15
#                                /                     \
#                               3 8                  19 24
#                          /     |     \       /       |       \
#                         1 2   5 6   9 10   16 18   20 21   25 26
#
# 13)
#                                   3 8 15 24
#                          /     /     |          \         \
#                         1 2   5 6   9 10   16 18 20 21   25 26
#
# 14) B-트리에서 특정 키의 직후 원소는 해당 키의 오른쪽 서브트리에서 가장 작은 값이다. 가장 작은 값을 찾기 위해서는 계속해서 왼쪽 자식으로 내려가야 하므로, 리프 노드까지 내려가게 된다.
#
# 15) (교수님께서 안 풀어도 된다고 하심.)
#
# 16) 모든 노드(루트 제외)는 최소 k/2개에서 최대 k개의 키를 가져야 한다.
#
# 17) 발생하지 않음. 각각 최소 키 수인 k/2-1개를 가질 때 병합하며, 부모에서 1개를 가져온다.
#     총 (k/2-1)x2+1 -> 약 m-1개로 최대 키 수인 m-1개를 넘지 않는다.
#
# 18) (교수님께서 안 풀어도 된다고 하심.)
#
# 19) (교수님께서 안 풀어도 된다고 하심.)
